# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Load the sample data
file_path = "sample_user_profiles.json"
df = pd.read_json(file_path)

# %%
# Convert user expertise into a text format for vectorization
def preprocess_expertise(row):
    expertise = row['resume']['expertise']
    text = " ".join(
        expertise.get('assetClasses', []) +
        expertise.get('products', []) +
        expertise.get('sectors', []) +
        expertise.get('regions', [])
    )
    return text

df['expertise_text'] = df.apply(preprocess_expertise, axis=1)

# %%
# Convert liked tags into a text format
df['tags_liked_text'] = df['tagsLiked'].apply(lambda x: " ".join(x))

# Combine all textual features for recommendation
df['profile_text'] = df['expertise_text'] + " " + df['tags_liked_text']

# %%
df
# Out:
#           guid     gpn businessName           businessTitle  \
# 0    PSI410000  410000       User 0        Research Analyst
# 1    PSI410001  410001       User 1  Global Markets - Sales
# 2    PSI410002  410002       User 2      Investment Banking
# 3    PSI410003  410003       User 3      Investment Banking
# 4    PSI410004  410004       User 4        Research Analyst
# ..         ...     ...          ...                     ...
# 195  PSI410195  410195     User 195        Research Analyst
# 196  PSI410196  410196     User 196  Global Markets - Sales
# 197  PSI410197  410197     User 197      Investment Banking
# 198  PSI410198  410198     User 198        Research Analyst
# 199  PSI410199  410199     User 199  Global Markets - Sales
#
#            employeeRank firstName lastName countryCode     countryName  \
# 0             Associate    First0    Last0          US           India
# 1     Managing Director    First1    Last1          IN           India
# 2     Managing Director    First2    Last2          IN  United Kingdom
# 3     Managing Director    First3    Last3          SG           India
# 4     Managing Director    First4    Last4          GB  United Kingdom
# ..                  ...       ...      ...         ...             ...
# 195  Executive Director  First195  Last195          SG       Singapore
# 196   Managing Director  First196  Last196          GB           India
# 197  Executive Director  First197  Last197          IN  United Kingdom
# 198  Executive Director  First198  Last198          GB           India
# 199           Associate  First199  Last199          US  United Kingdom
#
#                email                                             resume  \
# 0      user0@ubs.com  {'biography': 'User 0 has experience in financ...
# 1      user1@ubs.com  {'biography': 'User 1 has experience in financ...
# 2      user2@ubs.com  {'biography': 'User 2 has experience in financ...
# 3      user3@ubs.com  {'biography': 'User 3 has experience in financ...
# 4      user4@ubs.com  {'biography': 'User 4 has experience in financ...
# ..               ...                                                ...
# 195  user195@ubs.com  {'biography': 'User 195 has experience in fina...
# 196  user196@ubs.com  {'biography': 'User 196 has experience in fina...
# 197  user197@ubs.com  {'biography': 'User 197 has experience in fina...
# 198  user198@ubs.com  {'biography': 'User 198 has experience in fina...
# 199  user199@ubs.com  {'biography': 'User 199 has experience in fina...
#
#                          tagsLiked                            documentsLiked  \
# 0    [Stocks, Oil Prices, Mergers]    [doc_81, doc_69, doc_6, doc_60, doc_1]
# 1                 [Bonds, Mergers]                 [doc_49, doc_100, doc_73]
# 2                      [Tech IPOs]                                  [doc_84]
# 3                     [Oil Prices]                  [doc_51, doc_46, doc_21]
# 4      [Mergers, Tech IPOs, Bonds]                  [doc_78, doc_36, doc_64]
# ..                             ...                                       ...
# 195           [Oil Prices, Stocks]                          [doc_80, doc_78]
# 196           [Oil Prices, Stocks]          [doc_98, doc_94, doc_85, doc_77]
# 197   [Mergers, Tech IPOs, Stocks]                  [doc_55, doc_15, doc_61]
# 198                   [Oil Prices]  [doc_39, doc_76, doc_79, doc_48, doc_14]
# 199   [Oil Prices, Mergers, Bonds]                                  [doc_88]
#
#     documentsPublished                                     expertise_text  \
# 0             [doc_44]  Fixed Income Mutual Funds ETFs Technology Nort...
# 1             [doc_44]   Commodities Derivatives Technology North America
# 2      [doc_25, doc_4]  Equities Mutual Funds ETFs Technology Energy Asia
# 3     [doc_13, doc_47]  Equities ETFs Mutual Funds Healthcare North Am...
# 4     [doc_30, doc_37]  Fixed Income Commodities Derivatives ETFs Ener...
# ..                 ...                                                ...
# 195                 []  Fixed Income ETFs Energy Healthcare North America
# 196   [doc_14, doc_39]  Equities Fixed Income Commodities Mutual Funds...
# 197           [doc_40]  Fixed Income Mutual Funds Derivatives Healthca...
# 198           [doc_12]  Commodities ETFs Derivatives Healthcare North ...
# 199    [doc_37, doc_8]  Equities ETFs Mutual Funds Energy North Americ...
#
#                tags_liked_text  \
# 0    Stocks Oil Prices Mergers
# 1                Bonds Mergers
# 2                    Tech IPOs
# 3                   Oil Prices
# 4      Mergers Tech IPOs Bonds
# ..                         ...
# 195          Oil Prices Stocks
# 196          Oil Prices Stocks
# 197   Mergers Tech IPOs Stocks
# 198                 Oil Prices
# 199   Oil Prices Mergers Bonds
#
#                                           profile_text
# 0    Fixed Income Mutual Funds ETFs Technology Nort...
# 1    Commodities Derivatives Technology North Ameri...
# 2    Equities Mutual Funds ETFs Technology Energy A...
# 3    Equities ETFs Mutual Funds Healthcare North Am...
# 4    Fixed Income Commodities Derivatives ETFs Ener...
# ..                                                 ...
# 195  Fixed Income ETFs Energy Healthcare North Amer...
# 196  Equities Fixed Income Commodities Mutual Funds...
# 197  Fixed Income Mutual Funds Derivatives Healthca...
# 198  Commodities ETFs Derivatives Healthcare North ...
# 199  Equities ETFs Mutual Funds Energy North Americ...
#
# [200 rows x 17 columns]

# %%
# TF-IDF Vectorization
vectorizer = TfidfVectorizer()
profile_matrix = vectorizer.fit_transform(df['profile_text'])

# Compute similarity scores
similarity_matrix = cosine_similarity(profile_matrix)

# Save the model
joblib.dump((vectorizer, similarity_matrix, df), "/content/user_recommendation_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
from google.colab import files
files.download("/content/user_recommendation_model.pkl")

# %%
import joblib
import pandas as pd

# Load the trained model
vectorizer, similarity_matrix, df = joblib.load("/content/user_recommendation_model.pkl")
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
def recommend_articles(user_guid, top_n=5):
    if user_guid not in df['guid'].values:
        return f"User {user_guid} not found in the dataset."

    # Get index of the user
    user_idx = df[df['guid'] == user_guid].index[0]

    # Get similarity scores for this user
    sim_scores = list(enumerate(similarity_matrix[user_idx]))

    # Sort users by similarity score (excluding the user itself)
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:]

    # Get top N similar users
    top_users = [df.iloc[i[0]] for i in sim_scores[:top_n]]

    # Collect documents liked by similar users
    recommended_articles = set()
    user_liked_articles = set(df.iloc[user_idx]['documentsLiked'])

    for similar_user in top_users:
        for article in similar_user['documentsLiked']:
            if article not in user_liked_articles:
                recommended_articles.add(article)

    return list(recommended_articles)[:top_n]

# %%
# Pick the first user from the dataset
sample_user_guid = df.iloc[0]['guid']

# Get article recommendations
recommendations = recommend_articles(sample_user_guid, top_n=5)
print(f"Recommended articles for user {sample_user_guid}: {recommendations}")
# Out:
# Recommended articles for user PSI410000: ['doc_86', 'doc_72', 'doc_92', 'doc_90', 'doc_34']
